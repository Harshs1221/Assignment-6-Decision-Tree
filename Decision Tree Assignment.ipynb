# %%
#Q1. What is a Decision Tree, and how does it work?
"""
Ans1. A decision tree is a powerfull machine learning algorithm used for classification and regression tasks.
      A decision tree is like a flowchart that helps make decision by asking series of simple yes/no question.
      Image you're deciding what to wear:
      1. Is it raining -
              If yes, wear a raincoat
              If NP, move to the next question.
      2. Is it cold?
              If yes, wear a jacket.
              If no, wear a T-shirt.
        Each question leads to a decision, and this is how decision tree works- breaking a big decision imto smaller
        steps
"""

# %%
#Q2.  What are impurity measures in Decision Trees?
"""
Ans2. Impurity measures in Decision Tree help determine how well a dataset is split at each node.
      They quantify the homogeneity of the data-lower the impurity means better classification.

      Impurity Measures Types:
      1. Gini -
            Measures the probability of incorrect classification. A lower gini value means a purer node.
      2. Entropy:
            Based on information theory, it calculates the randomness in a dataset. Lower entropy means better splits.
      3. Classification Error:
            Simply counts the fraction of misclassified samples, but is less commonly used.
      4. Information Gain:
            The reduction in entropy after a split , helping choose the best feature for division.
"""

# %%
#Q3.  What is the mathematical formula for Gini Impurity?
"""
Ans3. G.I = 
            1-∑i=0 to n-1 (pi)**2
        where pi = is the probablitity of a class in the node
              n = is the total number of classes.
"""

# %%
#Q4. What is the mathematical formula for Entropy
"""Ans4. Formula of entropy is:      
                    𝐻(𝑆)=   −∑𝑖=1𝑛-1 𝑝𝑖 log2(𝑝𝑖)
"""

# %%
#Q5.  What is Information Gain, and how is it used in Decision Trees?
"""
Ans5. Information gain is a measure used in decision tree to determine the best feature for  splitting the data
      at each node. it quantifies the reduction in entropy after a split.
      It will be used for splitting the feature in decision tree, which feature has the maximum information gain, that
      will be used.
"""

# %%
#Q6. What is the difference between Gini Impurity and Entropy?
"""
Ans6. The differences between Gini Impurity and Entropy are:
        1. Mathematical Complexity:
               - Gini is easier to compute.
               - Entropy more computationally expensive.
        2. Raneg of values:
               - Gini between 0 and 0.5
               - Entropy between 0 and 1
        3. Interpretation:
               - Gini Measures missclassification probability.
               - Entropy Measures randomness or disorder.
        4. Preferred Use case:
               - Gini works well for larger datasets
               - Entropy more usefull for imbalanced datasets.
"""

# %%
#Q7.  What is the mathematical explanation behind Decision Trees?
"""
Ans7. A decision tree is a supervised leanring algorithm uses a tree like structure to make
      decisions.
      It works by recursively splitting data based on certain conditioins, aiming to maximize the 
      information gain or minimize impurity.
        Formula of entropy is:      
                    𝐻(𝑆)=   −∑𝑖=1𝑛-1 𝑝𝑖 log2(𝑝𝑖)

        G.I = 
            1-∑i=0 to n-1 (pi)**2
              where pi = is the probablitity of a class in the node
              n = is the total number of classes.

        Information Gain = 
                        impurity(pre-split) - impurity(post-split)      

     - Splitting criteria:
             The algorithm selects the feature that maximizes information gain and
             minimizes gini impuroty.
     - recursive Paririoning:
             The tree continues splitting until a stopping condition is met (e.g., pure nodes).
"""

# %%
#Q8. What is Pre-Pruning in Decision Trees?
"""
Ans8. Pre-Pruning is used to control the growth of the tree and preventing overfitting.
      It works bt applying constraints before the tree fully develops.
      - Hyperparameter tuning is used to select the best parameter.
      Some common pre pruning methods include:
      1. Setting a maximum depth:
                  Limits how deep the tree can grow.
      2. Minimums samples per split:
                  Ensures each splits has enough data points.
      3. Minimum leaf size:
                  Prevents tiny branches with very few samples
        
"""

# %%
#Q9. What is Post-Pruning in Decision Trees?
"""
Ans9. Post pruning in decision tree is a technique is used to simplify the tree after it has been
      fully grown.
      Post pruning allows the tree from growing too deep and then removes unnecessary branches to
      improve genralization.
"""

# %%
#Q10.  What is the difference between Pre-Pruning and Post-Pruning?
"""
Ans10. Difference between Pre-Pruning and Post-Pruning are:

        Pre-Pruning:
            1. Pre-Pruning happens before the tree is fully grown.
               Post-Pruning happens after the tree is fully grown.
            2. Pre-Pruning stops tree growth early using constraints(e.g., max_depth, min sample per split)
               Post-Pruning grows the full tree first, then remove the unnecessary branches.
            3. Prevent excessive complexity from the start.
               Simplify the tree after training.
            4. Risk- Might stop too early and important patterns.
               Post-pruning might remove useful branches if not done carefully. 
            
"""

# %%
#Q11.  What is a Decision Tree Regressor?
"""
Ans11. Decision Tree Regressor predicts continous numerical values instead of categories.
       It works by splitting the data into smaller regions based on feature values, similar to
       how a decision tree classifier works.
       In decision tree regressor we use variance instead of gini and entropy and variance
       reduction instaed of Imformation Gain.
"""

# %%
#Q12.  What are the advantages and disadvantages of Decision Trees?
"""
Ans12. Advantages:
        1. Easy to understand & Interpret:
                Decision trees are intutive and can be visualized.
        2. Handles both Numerical & Categorical Data:
                Works well with different types of data.
        3. No Need of Feature Scaling:
                Unlike SVM aor logistic regression, decision tree don't require normalization.
        4. Can Handle Missing Values:
                Some decision tree algorithms can work if the data is incomplete.
        5. Non-parametric:
                No assumption about data distribution are needed.
        6. Captures Non-Linear Relationships:
                Can model complex patterns in data.

                
        Disadvantages:
        1. Prone to Overfitting:
                If the tree grows too deep, it may memorize the training data instead of generalizing.
        2. Sensitive to Noisy Data:
                Small changes in data can lead to completely different trees.
        3. Greedy Algorithm:
                Decision tree use a greedy approach, which may not always find the best spkit.
        4. Computationally expensive for larger datasets.
        5. Less accurate compared to Ensembles methods.

"""

# %%
#Q13.  How does a Decision Tree handle missing values?
"""
Ans13. Decision tree handle missing value in several ways:
        1. Ignoring missing values during spltting:
                Some algorithms, like CART, can ignore missing values when chossing the
                best split.
        2. Assigning the probabilities to Missing Values
                Instead of removing missing values, decison tree can assign probabilities 
                based on existing data patterns.
        3. Using Surrogate Splits:
                If a primary feature has missing values, the tree finds and alternative
                (surrogate) feature that closely mimics the original split.
        4. Replacing Missing value with Mean/Median/Mode
                Some implementations replace missing values with the most common or
                average value in the dataset.
"""

# %%
#Q14.  How does a Decision Tree handle categorical features?
"""
Ans14. Decision tree can handle categorical features in different ways:
        1. Label encoding
            - Convert the categorical into numerical labels.(red- 1, blue -2)
            - Works well for ordinal categories.
        2. One Hot Encoding
            - Coverts categories into binary columns (e.g, "Red", 'Blue', 'Green' ->
                [1,0,0], [0,1,0],[0,0,1])
            - Prevent false ranking issues
        3. Decision Tree can handle categorical data directly like CART can split categorical
           features without encoding.
           For example: feature has Sunny, Rainy, Cloudy it splits directly (Sunny, Not sunny)
"""

# %%
#Q15. What are some real-world applications of Decision Trees?
"""
Ans15. Real life example if you want to buy alaptop. you ask yourself"
        1. Budget above 50,000 - Yes -> Look at high end laptops 
            -> No -> Look at budget friendly laptops
        2. Do you need gaming features -> Yes -> choose a gaming laptop -> No -> choose a
           regular laptop.

           Each question split into smaller decisions, just like a decision tree in machine learning.

        It can be used in:
        1. Healthcare -> Doctors use them to diagnose diseases based on symptoms.
        2. Finance -> banks decide whether to approve loans based on credit history.
        3. Marketing -> Comapnies predict customer preferences to reccomend products.
"""

# %%
#Practical Question

# %%
#Q16.  Write a Python program to train a Decision Tree Classifier on the Iris dataset and print the model accuracy.

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings("ignore")

# %%
from sklearn.datasets import load_iris

# %%
data = load_iris()

# %%
df = pd.DataFrame(data.data , columns= data.feature_names)

# %%
X = df
y = data.target

# %%
#train test split
from sklearn.model_selection import train_test_split
X_train,X_test, y_train, y_test = train_test_split(X,y, test_size= 0.2 , random_state = 1)

# %%
from sklearn.tree import DecisionTreeClassifier
cls = DecisionTreeClassifier(criterion='entropy')

# %%
cls
# Out:
# DecisionTreeClassifier(criterion='entropy')

# %%
cls.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy')

# %%
#visualize the tree
from sklearn import tree
tree.plot_tree(cls, filled = True)
plt.show()

# %%
# make prediction
y_pred = cls.predict(X_test)

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test, y_pred)
# Out:
# 0.9666666666666667

# %%
#Q17. Write a Python program to train a Decision Tree Classifier using Gini Impurity as the criterion and print the 
#     feature importances

# %%
data = load_iris()

# %%
df = pd.DataFrame(data.data , columns= data.feature_names)

# %%
X = df
y = data.target

# %%
#train test split
from sklearn.model_selection import train_test_split
X_train,X_test, y_train, y_test = train_test_split(X,y, test_size= 0.2 , random_state = 1)

# %%
from sklearn.tree import DecisionTreeClassifier
clf  = DecisionTreeClassifier(criterion="gini")

# %%
clf
# Out:
# DecisionTreeClassifier()

# %%
clf.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
clf.feature_importances_
# Out:
# array([0.        , 0.01880092, 0.08837961, 0.89281948])

# %%
#Q18. Write a Python program to train a Decision Tree Classifier using Entropy as the splitting criterion and print the 
#    model accuracy.

# %%
data = load_iris()

# %%
df = pd.DataFrame(data.data , columns= data.feature_names)

# %%
X = df
y = data.target

# %%
#train test split
from sklearn.model_selection import train_test_split
X_train,X_test, y_train, y_test = train_test_split(X,y, test_size= 0.2 , random_state = 1)

# %%
from sklearn.tree import DecisionTreeClassifier
clf =  DecisionTreeClassifier(criterion= 'entropy')

# %%
clf
# Out:
# DecisionTreeClassifier(criterion='entropy')

# %%
clf.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy')

# %%
y_pred = clf.predict(X_test)

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test, y_pred)
# Out:
# 0.9666666666666667

# %%
#Q19. Write a Python program to train a Decision Tree Regressor on a housing dataset and evaluate using Mean 
#     Squared Error (MSE)

# %%
from sklearn.datasets import fetch_california_housing

# %%
data = fetch_california_housing()

# %%
df = pd.DataFrame(data.data, columns=data.feature_names)

# %%
X = df
y = data.target

# %%
#train test split
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.8, random_state=1)

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
model = DecisionTreeRegressor()

# %%
model.fit(X_train, y_train)
# Out:
# DecisionTreeRegressor()

# %%
y_pred = model.predict(X_test)

# %%
from sklearn.metrics import mean_squared_error

# %%
mean_squared_error(y_test, y_pred)
# Out:
# 0.6372834428968024

# %%
#Q20. Write a Python program to train a Decision Tree Classifier and visualize the tree using graphviz.

# %%
data = load_iris()

# %%
df = pd.DataFrame(data.data , columns= data.feature_names)

# %%
X = df
y = data.target

# %%
#train test split
from sklearn.model_selection import train_test_split
X_train,X_test, y_train, y_test = train_test_split(X,y, test_size= 0.2 , random_state = 1)

# %%
from sklearn.tree import DecisionTreeClassifier
clf =  DecisionTreeClassifier(criterion= 'gini')
clf.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
from sklearn.tree import export_graphviz
import graphviz

# %%
dot_data = export_graphviz(clf, out_file = None,
                          feature_names=data.feature_names,
                          class_names=data.target_names,
                          filled = True, rounded= True, special_characters= True)

# %%
pip install graphviz
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
#Q21. Write a Python program to train a Decision Tree Classifier with a maximum depth of 3 and compare its 
# accuracy with a fully grown tree

# %%
data = load_iris()

# %%
df = pd.DataFrame(data.data , columns= data.feature_names)

# %%
X = df
y = data.target

# %%
#train test split
from sklearn.model_selection import train_test_split
X_train,X_test, y_train, y_test = train_test_split(X,y, test_size= 0.2 , random_state = 1)

# %%
from sklearn.tree import DecisionTreeClassifier
clf =  DecisionTreeClassifier(criterion= 'gini')
clf.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
from sklearn import tree
tree.plot_tree(clf, filled= True)
plt.show()

# %%
y_pred = clf.predict(X_test)

# %%
#accuracy for full grown tree
from sklearn.metrics import accuracy_score
acc= accuracy_score(y_test, y_pred)

# %%
from sklearn.tree import DecisionTreeClassifier
clf_depth =  DecisionTreeClassifier(criterion= 'gini', max_depth= 3)
clf_depth.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(max_depth=3)

# %%
tree.plot_tree(clf_depth, filled = True)
plt.show()

# %%
y_pred = clf_depth.predict(X_test)

# %%
#accuracy score for max depth 3
depth = accuracy_score(y_test, y_pred)

# %%
print(f'Accuracy score for full grown tree is {round(acc,2)}')
print(f'Accuracy score for tree max depth-3 is {round(depth,2)}')
# Out:
# Accuracy score for full grown tree is 0.97
# Accuracy score for tree max depth-3 is 0.97

# %%
#Q22. Write a Python program to train a Decision Tree Classifier using min_samples_split=5 and compare its 
#     accuracy with a default tree

# %%
data = load_iris()

# %%
df = pd.DataFrame(data.data , columns= data.feature_names)

# %%
X = df
y = data.target

# %%
#train test split
from sklearn.model_selection import train_test_split
X_train,X_test, y_train, y_test = train_test_split(X,y, test_size= 0.2 , random_state = 1)

# %%
clf = DecisionTreeClassifier(criterion='entropy')

# %%
clf
# Out:
# DecisionTreeClassifier(criterion='entropy')

# %%
clf.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy')

# %%
tree.plot_tree(clf, filled=True)
plt.show()

# %%
y_pred = clf.predict(X_test)

# %%
#aucracy
from sklearn.metrics import accuracy_score
acc= accuracy_score(y_test, y_pred)

# %%
clf_split = DecisionTreeClassifier(criterion='entropy', min_samples_split= 5)

# %%
clf_split
# Out:
# DecisionTreeClassifier(criterion='entropy', min_samples_split=5)

# %%
clf_split.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy', min_samples_split=5)

# %%
tree.plot_tree(clf_split, filled= True)
plt.show()

# %%
y_pred_split = clf_split.predict(X_test)

# %%
#accuracy score
defa = accuracy_score(y_test, y_pred_split)

# %%
print(F"Accuracy score for default tree is {acc}")
print(F"Accuracy score for tree min_sample_split is 5 {defa}")
# Out:
# Accuracy score for default tree is 0.9666666666666667
# Accuracy score for tree min_sample_split is 5 0.9666666666666667

# %%
#Q23. Write a Python program to apply feature scaling before training a Decision Tree Classifier and compare its 
#     accuracy with unscaled data

# %%
data = load_iris()

# %%
df = pd.DataFrame(data.data , columns= data.feature_names)

# %%
X = df
y = data.target

# %%
#train test split
from sklearn.model_selection import train_test_split
X_train,X_test, y_train, y_test = train_test_split(X,y, test_size= 0.2 , random_state = 1)

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

# %%
X_train_scaled = scaler.fit_transform(X_train)

# %%
X_test_scaled = scaler.transform(X_test)

# %%
scaled_cls = DecisionTreeClassifier(criterion='gini')

# %%
scaled_cls
# Out:
# DecisionTreeClassifier()

# %%
scaled_cls.fit(X_train_scaled,y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_pred_scaled = scaled_cls.predict(X_test_scaled)

# %%
scaled_acc = accuracy_score(y_test, y_pred_scaled)

# %%
#unscaled data
cls = DecisionTreeClassifier(criterion='gini')

# %%
cls.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_pred = clf.predict(X_test)

# %%
acc = accuracy_score(y_test, y_pred)

# %%
print(F"Accuracy score for scaled data is {scaled_acc}")
print(F"Accuracy score for default tree is {acc}")
# Out:
# Accuracy score for scaled data is 0.9666666666666667
# Accuracy score for default tree is 0.9666666666666667

# %%
#Q24. Write a Python program to train a Decision Tree Classifier using One-vs-Rest (OvR) strategy for multiclass 
#     classification.

# %%
data = load_iris()

# %%
df = pd.DataFrame(data.data , columns= data.feature_names)

# %%
X = df
y = data.target

# %%
#traintest split
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.3, random_state=1)

# %%
from sklearn.multiclass import OneVsOneClassifier

# %%
clf = OneVsOneClassifier(DecisionTreeClassifier(criterion='entropy'))

# %%
clf.fit(X_train, y_train)
# Out:
# OneVsOneClassifier(estimator=DecisionTreeClassifier(criterion='entropy'))

# %%
y_pred = clf.predict(X_test)

# %%
# accuracy score
accuracy_score(y_test, y_pred)
# Out:
# 0.9555555555555556

# %%
#Q25. Write a Python program to train a Decision Tree Classifier and display the feature importance scores

# %%
data = load_iris()

# %%
df = pd.DataFrame(data.data , columns= data.feature_names)

# %%
X = df
y = data.target

# %%
#traintest split
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.3, random_state=1)

# %%
clf = DecisionTreeClassifier(criterion='entropy')

# %%
clf.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy')

# %%
feature_imp = clf.feature_importances_

# %%
for feature, imp in zip(data.feature_names, feature_imp):
    print(f'{feature}: {imp:.4f}')
# Out:
# sepal length (cm): 0.0195
# sepal width (cm): 0.0195
# petal length (cm): 0.6747
# petal width (cm): 0.2862

# %%
#Q26. Write a Python program totrain a Decision Tree Regressor with max_depth=5 and compare its performance 
#     with an unrestricted tree

# %%
from sklearn.datasets import fetch_california_housing

# %%
data = fetch_california_housing()

# %%
df = pd.DataFrame(data.data, columns= data.feature_names)

# %%
X = df
y = data.target

# %%
#train_test Split
X_train, X_test, y_train, y_test = train_test_split(X,y , test_size=0.2, random_state=1)

# %%
model_max = DecisionTreeRegressor(max_depth=5)

# %%
model_max.fit(X_train, y_train)
# Out:
# DecisionTreeRegressor(max_depth=5)

# %%
y_pred_max = model_max.predict(X_test)

# %%
#unrestricted tree
model = DecisionTreeRegressor()

# %%
model.fit(X_train, y_train)
# Out:
# DecisionTreeRegressor()

# %%
y_pred = model.predict(X_test)

# %%
from sklearn.metrics import r2_score

# %%
r2_max = r2_score(y_test, y_pred_max)
r2 = r2_score(y_test, y_pred)

# %%
print(f"R2 for tree which max depth 5 is : {r2_max:.4f}")
print(f"R2 for unrestricted tree is : {r2:.4f}")
# Out:
# R2 for tree which max depth 5 is : 0.6135
# R2 for unrestricted tree is : 0.6209

# %%
#Q27. Write a Python program to train a Decision Tree Classifier, apply Cost Complexity Pruning (CCP), and 
#     visualize its effect on accuracy

# %%
data = load_iris()

# %%
df = pd.DataFrame(data.data , columns= data.feature_names)

# %%
X = df
y = data.target

# %%
#traintest split
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.3, random_state=1)

# %%
clf = DecisionTreeClassifier(random_state=1)

# %%
clf.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(random_state=1)

# %%
#find optimal value for CCP by checking cost complexity pruning
path = clf.cost_complexity_pruning_path(X_train, y_train)

# %%
#exclude the last ccp as it prune everything
ccp_alpha = path.ccp_alphas[:-1]

# %%
train_acc = []
test_Acc = []

# %%
for alpha in ccp_alpha:
    clf_pruned = DecisionTreeClassifier(random_state=1 , ccp_alpha = alpha)
    clf_pruned.fit(X_test,y_test)

# %%
#calculate the accuracy in training and testing sets
train_acc.append(accuracy_score(y_train, clf_pruned.predict(X_train)))
test_Acc.append(accuracy_score(y_test, clf_pruned.predict(X_test)))

# %%
plt.plot(ccp_alpha[:len(train_acc)], train_acc, marker="o")
plt.plot(ccp_alpha[:len(test_Acc)], test_Acc, marker="o")
plt.show()

# %%
train_acc
# Out:
# [0.9428571428571428]

# %%
test_Acc
# Out:
# [0.9777777777777777]

# %%
#Q28.  Write a Python program to train a Decision Tree Classifier and evaluate its performance using Precision, Recall, and F1-Score.

# %%
data = load_iris()

# %%
df = pd.DataFrame(data.data , columns= data.feature_names)

# %%
X = df
y = data.target

# %%
#traintest split
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.3, random_state=1)

# %%
from sklearn.tree import DecisionTreeClassifier
clf = DecisionTreeClassifier(criterion='gini')

# %%
clf.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_pred = clf.predict(X_test)

# %%
from sklearn.metrics import classification_report

# %%
#recall score
print(classification_report(y_test, y_pred, target_names=data.target_names))
# Out:
#               precision    recall  f1-score   support
#
#       setosa       1.00      1.00      1.00        14
#   versicolor       0.94      0.94      0.94        18
#    virginica       0.92      0.92      0.92        13
#
#     accuracy                           0.96        45
#    macro avg       0.96      0.96      0.96        45
# weighted avg       0.96      0.96      0.96        45

# %%
#Q29.  Write a Python program to train a Decision Tree Classifier and visualize the confusion matrix using seaborn.
data = load_iris()

# %%
df = pd.DataFrame(data.data , columns= data.feature_names)

# %%
X = df
y = data.target

# %%
#traintest split
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.3, random_state=1)

# %%
from sklearn.tree import DecisionTreeClassifier
clf = DecisionTreeClassifier(criterion='gini')

# %%
clf.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_pred = clf.predict(X_test)

# %%
from sklearn.metrics import confusion_matrix

# %%
cm = confusion_matrix(y_test, y_pred)

# %%
sns.heatmap(cm, annot = True, cmap = 'Blues', xticklabels=data.target_names, yticklabels=data.target_names)
plt.xlabel("Predicted Label")
plt.ylabel("true Label")
plt.title("Confusion Matrix for Decision Tree Classifier")
plt.show()

# %%
cm
# Out:
# array([[14,  0,  0],
#        [ 0, 17,  1],
#        [ 0,  1, 12]], dtype=int64)

# %%
#Q30.  Write a Python program to train a Decision Tree Classifier and use GridSearchCV to find the optimal values 
 #     for max_depth and min_samples_split.

# %%
data = load_iris()

# %%
df = pd.DataFrame(data.data , columns= data.feature_names)

# %%
X = df
y = data.target

# %%
#traintest split
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.3, random_state=1)

# %%
paramter = { "criterion": ["gini", "entropy", "log_loss"],
            "splitter" : ["best", "random"],
            "max_depth": [1,2,3,4,5,6,8,9],
            "min_samples_split": [1,2,3,4,5,6,8,9],
            "max_features": ["sqrt", "log2"]   
}

# %%
clf = DecisionTreeClassifier()

# %%
from sklearn.model_selection import GridSearchCV
model = GridSearchCV(clf,param_grid = paramter, cv= 5, scoring = "accuracy", verbose = 3)

# %%
model
# Out:
# GridSearchCV(cv=5, estimator=DecisionTreeClassifier(),
#              param_grid={'criterion': ['gini', 'entropy', 'log_loss'],
#                          'max_depth': [1, 2, 3, 4, 5, 6, 8, 9],
#                          'max_features': ['sqrt', 'log2'],
#                          'min_samples_split': [1, 2, 3, 4, 5, 6, 8, 9],
#                          'splitter': ['best', 'random']},
#              scoring='accuracy', verbose=3)

# %%
model.fit(X_train,y_train)
# Out:
# Fitting 5 folds for each of 768 candidates, totalling 3840 fits
# [CV 1/5] END criterion=gini, max_depth=1, max_features=sqrt, min_samples_split=1, splitter=best;, score=nan total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=1, max_features=sqrt, min_samples_split=1, splitter=best;, score=nan total time=   0.0s
# [CV 3/5] END criterion=gini, max_depth=1, max_features=sqrt, min_samples_split=1, splitter=best;, score=nan total time=   0.0s
# [CV 4/5] END criterion=gini, max_depth=1, max_features=sqrt, min_samples_split=1, splitter=best;, score=nan total time=   0.0s
# [CV 5/5] END criterion=gini, max_depth=1, max_features=sqrt, min_samples_split=1, splitter=best;, score=nan total time=   0.0s
# [CV 1/5] END criterion=gini, max_depth=1, max_features=sqrt, min_samples_split=1, splitter=random;, score=nan total time=   0.0s
# [CV 2/5] END criterion=gini, max_depth=1, max_features=sqrt, min_samples_split=1, splitter=random;, score=nan total time=   0.0s
# ...

# %%
model.best_params_
# Out:
# {'criterion': 'gini',
#  'max_depth': 8,
#  'max_features': 'sqrt',
#  'min_samples_split': 8,
#  'splitter': 'best'}
